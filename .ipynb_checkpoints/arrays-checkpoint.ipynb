# %%
import numpy as np
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
os.chdir("C:\\Users\\SADHANA\\OneDrive\\Documents\\Desktop\\PYTHON\\Jupyter Notebook\\CSV")
sns.set(rc={"figure.figsize":(11.7,8.27)})

# %%
dataset=pd.read_csv("housing.csv")

# %%
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
dataset.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
datacopy=dataset.copy()

# %% [raw]
# datacopy

# %%
datacopy.drop(columns=["mainroad","guestroom","basement","hotwaterheating","airconditioning","prefarea","furnishingstatus"])
# Out:
#         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]

# %%
datacopy.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
pd.set_option("display.float_format",lambda x: "%.3f"%x)
datacopy.describe()
# Out:
#              price      area  bedrooms  bathrooms  stories  parking
# count      545.000   545.000   545.000    545.000  545.000  545.000
# mean   4766729.248  5150.541     2.965      1.286    1.806    0.694
# std    1870439.616  2170.141     0.738      0.502    0.867    0.862
# min    1750000.000  1650.000     1.000      1.000    1.000    0.000
# 25%    3430000.000  3600.000     2.000      1.000    1.000    0.000
# 50%    4340000.000  4600.000     3.000      1.000    2.000    0.000
# 75%    5740000.000  6360.000     3.000      2.000    2.000    1.000
# max   13300000.000 16200.000     6.000      4.000    4.000    3.000

# %%
sns.regplot(x="area",y="price",data=datacopy,scatter=True)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
lrg=linear_model.LinearRegression()
x=datacopy[["area","bedrooms","bathrooms","stories","parking"]]
y=datacopy["price"]

# %%
lrg.fit(x,y)
# Out:
# LinearRegression()

# %%
predicted=lrg.predict([[2400,3,1,1,0]])
# Out:
# C:\Users\SADHANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(predicted)
# Out:
# [2834052.0356451]

# %%
# Assuming datacopy is your DataFrame
x = datacopy[["area", "bedrooms", "bathrooms", "stories", "parking"]]
y = datacopy["price"]

# Specify feature names explicitly
feature_names = ["area", "bedrooms", "bathrooms", "stories", "parking"]
x.columns = feature_names

# Create and fit the linear regression model
lrg = linear_model.LinearRegression()
lrg.fit(x, y)

# Make predictions
predicted = lrg.predict([[2400, 3, 1, 1, 0]])
# Out:
# C:\Users\SADHANA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted
# Out:
# array([2834052.0356451])

# %%
import numpy as np
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
os.chdir("C:\\Users\\SADHANA\\OneDrive\\Documents\\Desktop\\PYTHON\\Jupyter Notebook\\CSV")
sns.set(rc={"figure.figsize":(11.7,8.27)})

# %%
datas = pd.read_csv("housing.csv")

# %%
datas
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
datas.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data = datas.copy()

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...
